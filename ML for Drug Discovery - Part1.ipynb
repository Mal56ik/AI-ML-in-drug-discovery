# %% [markdown]
# # **Machine Learning (ML) For Drug Discovery - Part 1**
# This is a complete technology crash course, where you will get a fair idea that how ML works, and how can you use it for a project of Drug Discovery. I have tried my level best to keep things simple, and you do not feel any need to code, therefore, I must say, it suits biologist. Here, I want to acknowledge and refer materials of Dr. Chanin Nantasenamat an Associate professor in Bioinformatics. These materials are compilled by **Dr. Ashfaq Ahmad**.
#
# ## **ChEMBL Database**
#
# (https://www.ebi.ac.uk/chembl/)
#
# ChEMBL is a manually curated database of bioactive molecules with drug-like properties. It brings together chemicals, their bioactivity and genomic data to aid the translation of genomic information into effective new drugs.
#
# (**Citation:** *Nucleic Acids Res. 2019; 47(D1):D930-D940. doi: 10.1093/nar/gky1075*)
#
# I will train you on the use and importance of ChEMBL database during this part of training. I will also teach you how can we pick and process data from the ChEMBL database.
#
# You will be required to execute the cells by clicking the ***Play*** button, with certain changes as per your project details.
#
#
# ### **Step 1 - Installing and Import Required Libraries**
#
# Running the following cell will install ChEMBL webresources for the project to initiate.
# Citation: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4489283/

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /usr/local/lib/python3.11/dist-packages (0.10.9)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (2.4.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (2.32.3)
# Requirement already satisfied: requests-cache~=1.2 in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (1.2.1)
# Requirement already satisfied: easydict in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2025.4.26)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.3.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.1.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.8)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.14.0)

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ### **Step 2 - Picking your desired Target from ChEMBL**
#
# Here we will launch search for the desired target protein or enzyme. To overcome any possibility of a potential mistake, it is highly advised also to confirm you ChEMBL ID from the direct database (ChEMBL) search.

# %%
# As an example I will use P2Y purinoceptor 1 protein (UniProt Accession P47900)
target = new_client.target
target_query = target.search('CHEMBL4315')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references      organism                 pref_name  score  \
# 0               []  Homo sapiens  Purinergic receptor P2Y1   16.0
# 1               []  Homo sapiens              P2Y receptor    7.0
#
#    species_group_flag target_chembl_id  \
# 0               False       CHEMBL4315
# 1               False    CHEMBL4524011
#
#                                    target_components     target_type  tax_id
# 0  [{'accession': 'P47900', 'component_descriptio...  SINGLE PROTEIN    9606
# 1  [{'accession': 'Q9H244', 'component_descriptio...  PROTEIN FAMILY    9606

# %% [markdown]
# ### **Step 3 - Selection and Retrieval Bioactivity data**
#
# In case you are hit with multiple data lines, then you need to choose the desired data, using the index number below in the cell.

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL4315'

# %% [markdown]
# If you carefully look to the data columns, you will find variety of variable. Here we are interested to perform analysis for Antagonist, therefore, I will go with IC50 column. Please read about IC50 values incase you are not aware.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 352  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 353  {'action_type': 'AGONIST', 'description': 'Bin...             None
# 354  {'action_type': 'AGONIST', 'description': 'Bin...             None
# 355  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 356  {'action_type': 'ANTAGONIST', 'description': '...             None
#
#      activity_id                                activity_properties  \
# 0          33943                                                 []
# 1          68995                                                 []
# 2         989362                                                 []
# 3         989364                                                 []
# 4         993873                                                 []
# ..           ...                                                ...
# 352     25089840                                                 []
# 353     25089842                                                 []
# 354     25089843                                                 []
# 355     25089889                                                 []
# 356     25702237  [{'comments': None, 'relation': '=', 'result_f...
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL751769  The compound was evaluated for antagonistic ac...
# 1      CHEMBL751769  The compound was evaluated for antagonistic ac...
# 2      CHEMBL750159   Antagonistic activity against P2Y purinoceptor 1
# 3      CHEMBL750159   Antagonistic activity against P2Y purinoceptor 1
# 4      CHEMBL750159   Antagonistic activity against P2Y purinoceptor 1
# ..              ...                                                ...
# 352   CHEMBL5257728                           Inhibition of human P2Y1
# 353   CHEMBL5257729                     Agonist activity at human P2Y1
# 354   CHEMBL5257729                     Agonist activity at human P2Y1
# 355   CHEMBL5257745            Inhibition of human P2Y1 by FLIPR assay
# 356   CHEMBL5385288  Antagonist activity at human P2Y1R expressed i...
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0            F                    None                   None  BAO_0000190
# 1            F                    None                   None  BAO_0000190
# 2            F                    None                   None  BAO_0000190
# 3            F                    None                   None  BAO_0000190
# 4            F                    None                   None  BAO_0000190
# ..         ...                     ...                    ...          ...
# 352          B                    None                   None  BAO_0000190
# 353          B                    None                   None  BAO_0000190
# 354          B                    None                   None  BAO_0000190
# 355          B                    None                   None  BAO_0000190
# 356          F                    None                   None  BAO_0000190
#
#      ... target_organism          target_pref_name target_tax_id text_value  \
# 0    ...    Homo sapiens  Purinergic receptor P2Y1          9606       None
# 1    ...    Homo sapiens  Purinergic receptor P2Y1          9606       None
# 2    ...    Homo sapiens  Purinergic receptor P2Y1          9606       None
# 3    ...    Homo sapiens  Purinergic receptor P2Y1          9606       None
# 4    ...    Homo sapiens  Purinergic receptor P2Y1          9606       None
# ..   ...             ...                       ...           ...        ...
# 352  ...    Homo sapiens  Purinergic receptor P2Y1          9606       None
# 353  ...    Homo sapiens  Purinergic receptor P2Y1          9606       None
# 354  ...    Homo sapiens  Purinergic receptor P2Y1          9606       None
# 355  ...    Homo sapiens  Purinergic receptor P2Y1          9606       None
# 356  ...    Homo sapiens  Purinergic receptor P2Y1          9606       None
#
#      toid  type units    uo_units upper_value  value
# 0    None  IC50    uM  UO_0000065        None    1.0
# 1    None  IC50    uM  UO_0000065        None    3.0
# 2    None  IC50    nM  UO_0000065        None  377.0
# 3    None  IC50    nM  UO_0000065        None  452.0
# 4    None  IC50    nM  UO_0000065        None  356.0
# ..    ...   ...   ...         ...         ...    ...
# 352  None  IC50    uM  UO_0000065        None    2.1
# 353  None  IC50    uM  UO_0000065        None    5.8
# 354  None  IC50    uM  UO_0000065        None   0.84
# 355  None  IC50    nM  UO_0000065        None   0.12
# 356  None  IC50    uM  UO_0000065        None   0.35
#
# [357 rows x 46 columns]

# %% [markdown]
# Lets play with the above data that contains too many rows and columns. By running the below command, you will only see the first four data lines.

# %%
df.head(4)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None        33943                  []
# 1        None             None        68995                  []
# 2        None             None       989362                  []
# 3        None             None       989364                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL751769  The compound was evaluated for antagonistic ac...
# 1    CHEMBL751769  The compound was evaluated for antagonistic ac...
# 2    CHEMBL750159   Antagonistic activity against P2Y purinoceptor 1
# 3    CHEMBL750159   Antagonistic activity against P2Y purinoceptor 1
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          F                    None                   None  BAO_0000190  ...
# 1          F                    None                   None  BAO_0000190  ...
# 2          F                    None                   None  BAO_0000190  ...
# 3          F                    None                   None  BAO_0000190  ...
#
#   target_organism          target_pref_name target_tax_id text_value  toid  \
# 0    Homo sapiens  Purinergic receptor P2Y1          9606       None  None
# 1    Homo sapiens  Purinergic receptor P2Y1          9606       None  None
# 2    Homo sapiens  Purinergic receptor P2Y1          9606       None  None
# 3    Homo sapiens  Purinergic receptor P2Y1          9606       None  None
#
#    type units    uo_units upper_value  value
# 0  IC50    uM  UO_0000065        None    1.0
# 1  IC50    uM  UO_0000065        None    3.0
# 2  IC50    nM  UO_0000065        None  377.0
# 3  IC50    nM  UO_0000065        None  452.0
#
# [4 rows x 46 columns]

# %% [markdown]
# The standard_type column in the data contains IC50. If you want to validate, so better to search for the unique features in the standard_type

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Now, here I want you to save your data in the Google Drive. For ease, you need first to connect your gdrive to this notebook.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)

# %% [markdown]
# Once the drive is mounted, please make a new folder with a name data where you can save your work directly

# %%
! ls /content/gdrive/MyDrive/

# %%
! mkdir "/content/gdrive/MyDrive/Colab Notebooks/data"

# %% [markdown]
# Now we are now in a position to save our data in a CSV file. I will use the name Bioactivity_data.csv

# %%
df.to_csv('P2Y1-01-bioactivity_data_raw.csv', index=False)

# %%
! cp P2Y1-01-bioactivity_data_raw.csv "/content/gdrive/MyDrive/Colab Notebooks/data"

# %%
ls "/content/gdrive/MyDrive/Colab Notebooks/data"

# %% [markdown]
# How our data looks like, take a look if you want to

# %%
! head P2Y1-01-bioactivity_data_raw.csv

# %% [markdown]
# ### **Step 4 - Treating Missing Data**
#
# There comes a possibility that some of the ChEMBL compounds may contain missing value for the **standared_value (IC50)** and **canonical_smiles**. Therefore, we need to remove such entries from the data.

# %%
df2 = df[df.standard_value.notna()]

# %%
df2 = df[df.canonical_smiles.notna()]

# %%
df2
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 352  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 353  {'action_type': 'AGONIST', 'description': 'Bin...             None
# 354  {'action_type': 'AGONIST', 'description': 'Bin...             None
# 355  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 356  {'action_type': 'ANTAGONIST', 'description': '...             None
#
#      activity_id                                activity_properties  \
# 0          33943                                                 []
# 1          68995                                                 []
# 2         989362                                                 []
# 3         989364                                                 []
# 4         993873                                                 []
# ..           ...                                                ...
# 352     25089840                                                 []
# 353     25089842                                                 []
# 354     25089843                                                 []
# 355     25089889                                                 []
# 356     25702237  [{'comments': None, 'relation': '=', 'result_f...
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL751769  The compound was evaluated for antagonistic ac...
# 1      CHEMBL751769  The compound was evaluated for antagonistic ac...
# 2      CHEMBL750159   Antagonistic activity against P2Y purinoceptor 1
# 3      CHEMBL750159   Antagonistic activity against P2Y purinoceptor 1
# 4      CHEMBL750159   Antagonistic activity against P2Y purinoceptor 1
# ..              ...                                                ...
# 352   CHEMBL5257728                           Inhibition of human P2Y1
# 353   CHEMBL5257729                     Agonist activity at human P2Y1
# 354   CHEMBL5257729                     Agonist activity at human P2Y1
# 355   CHEMBL5257745            Inhibition of human P2Y1 by FLIPR assay
# 356   CHEMBL5385288  Antagonist activity at human P2Y1R expressed i...
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0            F                    None                   None  BAO_0000190
# 1            F                    None                   None  BAO_0000190
# 2            F                    None                   None  BAO_0000190
# 3            F                    None                   None  BAO_0000190
# 4            F                    None                   None  BAO_0000190
# ..         ...                     ...                    ...          ...
# 352          B                    None                   None  BAO_0000190
# 353          B                    None                   None  BAO_0000190
# 354          B                    None                   None  BAO_0000190
# 355          B                    None                   None  BAO_0000190
# 356          F                    None                   None  BAO_0000190
#
#      ... target_organism          target_pref_name target_tax_id text_value  \
# 0    ...    Homo sapiens  Purinergic receptor P2Y1          9606       None
# 1    ...    Homo sapiens  Purinergic receptor P2Y1          9606       None
# 2    ...    Homo sapiens  Purinergic receptor P2Y1          9606       None
# 3    ...    Homo sapiens  Purinergic receptor P2Y1          9606       None
# 4    ...    Homo sapiens  Purinergic receptor P2Y1          9606       None
# ..   ...             ...                       ...           ...        ...
# 352  ...    Homo sapiens  Purinergic receptor P2Y1          9606       None
# 353  ...    Homo sapiens  Purinergic receptor P2Y1          9606       None
# 354  ...    Homo sapiens  Purinergic receptor P2Y1          9606       None
# 355  ...    Homo sapiens  Purinergic receptor P2Y1          9606       None
# 356  ...    Homo sapiens  Purinergic receptor P2Y1          9606       None
#
#      toid  type units    uo_units upper_value  value
# 0    None  IC50    uM  UO_0000065        None    1.0
# 1    None  IC50    uM  UO_0000065        None    3.0
# 2    None  IC50    nM  UO_0000065        None  377.0
# 3    None  IC50    nM  UO_0000065        None  452.0
# 4    None  IC50    nM  UO_0000065        None  356.0
# ..    ...   ...   ...         ...         ...    ...
# 352  None  IC50    uM  UO_0000065        None    2.1
# 353  None  IC50    uM  UO_0000065        None    5.8
# 354  None  IC50    uM  UO_0000065        None   0.84
# 355  None  IC50    nM  UO_0000065        None   0.12
# 356  None  IC50    uM  UO_0000065        None   0.35
#
# [357 rows x 46 columns]

# %%
len(df2.canonical_smiles.unique())

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])

# %%
df2_nr
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 343  {'action_type': 'ANTAGONIST', 'description': '...             None
# 344  {'action_type': 'ANTAGONIST', 'description': '...             None
# 345  {'action_type': 'ANTAGONIST', 'description': '...             None
# 346  {'action_type': 'ANTAGONIST', 'description': '...             None
# 353  {'action_type': 'AGONIST', 'description': 'Bin...             None
#
#      activity_id activity_properties assay_chembl_id  \
# 0          33943                  []    CHEMBL751769
# 1          68995                  []    CHEMBL751769
# 2         989362                  []    CHEMBL750159
# 3         989364                  []    CHEMBL750159
# 4         993873                  []    CHEMBL750159
# ..           ...                 ...             ...
# 343     24773444                  []   CHEMBL5127323
# 344     24773445                  []   CHEMBL5127323
# 345     24773446                  []   CHEMBL5127323
# 346     24773447                  []   CHEMBL5127323
# 353     25089842                  []   CHEMBL5257729
#
#                                      assay_description assay_type  \
# 0    The compound was evaluated for antagonistic ac...          F
# 1    The compound was evaluated for antagonistic ac...          F
# 2     Antagonistic activity against P2Y purinoceptor 1          F
# 3     Antagonistic activity against P2Y purinoceptor 1          F
# 4     Antagonistic activity against P2Y purinoceptor 1          F
# ..                                                 ...        ...
# 343  Antagonist activity at P2Y1 receptor (unknown ...          F
# 344  Antagonist activity at P2Y1 receptor (unknown ...          F
# 345  Antagonist activity at P2Y1 receptor (unknown ...          F
# 346  Antagonist activity at P2Y1 receptor (unknown ...          F
# 353                     Agonist activity at human P2Y1          B
#
#     assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                      None                   None  BAO_0000190  ...
# 1                      None                   None  BAO_0000190  ...
# 2                      None                   None  BAO_0000190  ...
# 3                      None                   None  BAO_0000190  ...
# 4                      None                   None  BAO_0000190  ...
# ..                      ...                    ...          ...  ...
# 343                    None                   None  BAO_0000190  ...
# 344                    None                   None  BAO_0000190  ...
# 345                    None                   None  BAO_0000190  ...
# 346                    None                   None  BAO_0000190  ...
# 353                    None                   None  BAO_0000190  ...
#
#     target_organism          target_pref_name target_tax_id text_value  toid  \
# 0      Homo sapiens  Purinergic receptor P2Y1          9606       None  None
# 1      Homo sapiens  Purinergic receptor P2Y1          9606       None  None
# 2      Homo sapiens  Purinergic receptor P2Y1          9606       None  None
# 3      Homo sapiens  Purinergic receptor P2Y1          9606       None  None
# 4      Homo sapiens  Purinergic receptor P2Y1          9606       None  None
# ..              ...                       ...           ...        ...   ...
# 343    Homo sapiens  Purinergic receptor P2Y1          9606       None  None
# 344    Homo sapiens  Purinergic receptor P2Y1          9606       None  None
# 345    Homo sapiens  Purinergic receptor P2Y1          9606       None  None
# 346    Homo sapiens  Purinergic receptor P2Y1          9606       None  None
# 353    Homo sapiens  Purinergic receptor P2Y1          9606       None  None
#
#      type units    uo_units upper_value  value
# 0    IC50    uM  UO_0000065        None    1.0
# 1    IC50    uM  UO_0000065        None    3.0
# 2    IC50    nM  UO_0000065        None  377.0
# 3    IC50    nM  UO_0000065        None  452.0
# 4    IC50    nM  UO_0000065        None  356.0
# ..    ...   ...         ...         ...    ...
# 343  IC50    uM  UO_0000065        None   0.48
# 344  IC50    uM  UO_0000065        None    1.6
# 345  IC50    uM  UO_0000065        None   1.09
# 346  IC50    uM  UO_0000065        None   0.84
# 353  IC50    uM  UO_0000065        None    5.8
#
# [245 rows x 46 columns]

# %% [markdown]
# ### **Step 5 - Data Preprocessing**
#
# We will be interested to keep record of the three columns, **ChEMBL_id**, **canonical_smiles**, and **standard_value**.

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]

# %%
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL133572  Nc1c(S(=O)(=O)[O-])cc(Nc2ccc(Nc3nc(Cl)nc(Cl)n3...
# 1         CHEMBL133576  Cc1cc(C)c(Nc2cc(S(=O)(=O)[O-])c(N)c3c2C(=O)c2c...
# 2         CHEMBL356041  CNc1nc([Se]C)nc2c1ncn2C1CC(OP(=O)(O)O)[C@]2(CO...
# 3        CHEMBL2112869  CCCCCCc1nc(NC)c2ncn([C@H]3C[C@H](OP(=O)(O)O)[C...
# 4        CHEMBL2112868  CNc1nc(F)nc2c1ncn2[C@H]1C[C@H](OP(=O)(O)O)[C@]...
# ..                 ...                                                ...
# 343       CHEMBL432028         CNc1ncnc2c1ncn2CCC(COP(=O)(O)O)COP(=O)(O)O
# 344       CHEMBL108166     CNc1nc(Cl)nc2c1ncn2CCC(COP(=O)(O)O)COP(=O)(O)O
# 345       CHEMBL320924          CNc1ncnc2c1ncn2CC(COP(=O)(O)O)COP(=O)(O)O
# 346       CHEMBL104784      CNc1nc(Cl)nc2c1ncn2CC(COP(=O)(O)O)COP(=O)(O)O
# 353      CHEMBL1230817  Nc1ncnc2c1ncn2[C@H]1C[C@H](OP(=O)(O)O)[C@@H](C...
#
#     standard_value
# 0           1000.0
# 1           3000.0
# 2            377.0
# 3            452.0
# 4            356.0
# ..             ...
# 343          480.0
# 344         1600.0
# 345         1090.0
# 346          840.0
# 353         5800.0
#
# [245 rows x 3 columns]

# %% [markdown]
# Now we need to save data frame or the df3 to the CSV file.

# %%
df3.to_csv('P2Y1-bioactivity-data-02-preprocessed.csv', index=False)

# %% [markdown]
# ### **Step 6 - Labeling compounds to different categories**
#
# Here we will need to categorize these compounds into different catergories, based on the IC50 value or **standard_value**. For the purpose, we will classify three groups, **Active**, **Inactive**, **Intermediate**. Compounds with IC50 value less than 1000 nM will be considered active drugs, those greater than 10,000 nM will be considered inactive and IC50 value in greater than 1000 and below 10,000 will be termed as intermediate.

# %%
df4 = pd.read_csv('P2Y1-bioactivity-data-02-preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)

# %%
df5
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL152758          CC(N[C@H](C)C(=O)N1CCC[C@H]1C(=O)O)C(=O)O
# 1         CHEMBL291381                        O=C(CCC(=O)N1CCCC1C(=O)O)NO
# 2         CHEMBL358439            C[C@@H](NCC(=O)O)C(=O)N1CCC[C@H]1C(=O)O
# 3           CHEMBL1237  NCCCC[C@H](N[C@@H](CCc1ccccc1)C(=O)O)C(=O)N1CC...
# 4         CHEMBL293213                     CC(CCC(=O)N1CCCC1C(=O)O)C(=O)O
# ..                 ...                                                ...
# 750      CHEMBL5429562  CC[C@H](C)[C@@H]1NC(=O)[C@H](CCCNC(=N)N)NC(=O)...
# 751      CHEMBL5397691  CC[C@H](C)[C@@H]1NC(=O)[C@H](CCCNC(=N)N)NC(=O)...
# 752      CHEMBL5415414  CC[C@H](C)[C@@H]1NC(=O)[C@H](CCCNC(=N)N)NC(=O)...
# 753      CHEMBL5400083  CC[C@H](C)[C@@H]1NC(=O)[C@H](CCCCNC(=N)N)NC(=O...
# 754      CHEMBL5402781                      Cc1oc(C)c(S(N)(=O)=O)c1C(=O)O
#
#      standard_value units         class
# 0              90.0    uM        active
# 1           50000.0    uM      inactive
# 2            2400.0    uM  intermediate
# 3               1.2    nM        active
# 4          260000.0    uM      inactive
# ..              ...   ...           ...
# 750            40.0    nM        active
# 751            40.0    nM        active
# 752            40.0    nM        active
# 753            40.0    nM        active
# 754       1000000.0    uM      inactive
#
# [755 rows x 5 columns]

# %% [markdown]
# Now we need to save the above dataframe or df5 to the CSV file.

# %%
df5.to_csv('P2Y1_03_bioactivity_data_curated.csv', index=False)

# %%
! zip P2Y1-part1-data.zip *.csv

# %%
! cp P2Y1_03_bioactivity_data_curated.csv "/content/gdrive/MyDrive/Colab Notebooks/data"

# %%
ls "/content/gdrive/MyDrive/Colab Notebooks/data"
